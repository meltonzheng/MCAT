# %%
import pandas as pd

dat = pd.read_csv('dataset.csv')

# %%
dat
# Out:
#          r/MCAT   Unnamed: 1 DA REAL SHIT  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0     Exam Date  Total Score    C/P Score  CARS Score  B/B Score  P/S Score
# 1    2019-05-18          514          130         127        128        129
# 2    2019-05-18          506          126         126        126        128
# 3    2019-05-18          513          129         127        130        127
# 4    2019-05-18          512          130         129        125        128
# ..          ...          ...          ...         ...        ...        ...
# 503  2019-09-06          514          129         129        129        127
# 504  2019-05-25          514          129         127        130        128
# 505  2019-09-14          521          130         130        129        132
# 506  2019-09-14          518          132         126        130        130
# 507  2019-09-14          517          129         128        131        129
#
# ...
